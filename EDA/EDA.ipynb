# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../datasets/cars_cleaned.csv")
df.sample(10)
# Out:
#           Model   Paliwo Typ nadwozia  Przebieg       Kolor  Poj. silnika  \
# 7441   Sportage   Diesel          SUV    130000      Czarny        2000.0
# 10345   Seria 1   Diesel    Hatchback    190000   Niebieski        1995.0
# 2714        207  Benzyna    Hatchback    204774       Szary        1397.0
# 9030     Touran   Diesel      Minivan    189101      Czarny        1598.0
# 2353     Galaxy   Diesel      Minivan    300000  Inny kolor        1997.0
# 9038      Fabia  Benzyna        Sedan    217500  Inny kolor        1390.0
# 5732          6   Diesel        Kombi    209000    Czerwony        2200.0
# 6516       Leon  Benzyna    Hatchback    248000      Czarny        1800.0
# 8182      Corsa  Benzyna    Hatchback    199000  Inny kolor        1229.0
# 782      Zafira  Benzyna      Minivan    361000      Czarny        1800.0
#
#       Skrzynia biegów Kraj pochodzenia  Moc silnika             Napęd  \
# 7441         Manualna           Polska        140.0  Na przednie koła
# 10345        Manualna      Brak danych        150.0     Na tylne koła
# 2714         Manualna           Niemcy         95.0  Na przednie koła
# 9030         Manualna      Brak danych        105.0  Na przednie koła
# 2353         Manualna      Brak danych        140.0  Na przednie koła
# 9038         Manualna           Polska         75.0  Na przednie koła
# 5732         Manualna           Niemcy        175.0  Na przednie koła
# 6516         Manualna      Brak danych        240.0  Na przednie koła
# 8182         Manualna           Polska         86.0  Na przednie koła
# 782          Manualna      Brak danych        140.0       Brak danych
#
#         Kierownica     Cena         Województwo Rodzaj ogłoszenia   Producent  \
# 7441      po lewej  21900.0             Łódzkie          Prywatne         Kia
# 10345     po lewej  39999.0         Mazowieckie          Prywatne         BMW
# 2714      po lewej   7500.0       Wielkopolskie          Prywatne     Peugeot
# 9030      po lewej  27500.0           Pomorskie           Firmowe  Volkswagen
# 2353      po lewej   9777.0       Wielkopolskie           Firmowe        Ford
# 9038      po lewej   2699.0        Dolnośląskie          Prywatne       Skoda
# 5732      po lewej  37500.0         Małopolskie          Prywatne       Mazda
# 6516     po prawej   7000.0           Podlaskie           Firmowe        Seat
# 8182      po lewej  17500.0             Śląskie          Prywatne        Opel
# 782    Brak danych   4900.0  Zachodniopomorskie          Prywatne        Opel
#
#        Czy cena do negocjacji  Wiek
# 7441                     True    16
# 10345                    True    10
# 2714                     True    18
# 9030                     True    14
# 2353                    False    19
# 9038                     True    20
# 5732                     True    10
# 6516                    False    23
# 8182                     True    12
# 782                      True    23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11766 entries, 0 to 11765
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Model                   11766 non-null  object
#  1   Paliwo                  11766 non-null  object
#  2   Typ nadwozia            11766 non-null  object
#  3   Przebieg                11766 non-null  int64
#  4   Kolor                   11766 non-null  object
#  5   Poj. silnika            11766 non-null  float64
#  6   Skrzynia biegów         11766 non-null  object
#  7   Kraj pochodzenia        11766 non-null  object
#  8   Moc silnika             11766 non-null  float64
#  9   Napęd                   11766 non-null  object
#  10  Kierownica              11766 non-null  object
#  11  Cena                    11766 non-null  float64
#  12  Województwo             11766 non-null  object
#  13  Rodzaj ogłoszenia       11766 non-null  object
#  14  Producent               11766 non-null  object
#  15  Czy cena do negocjacji  11766 non-null  bool
#  16  Wiek                    11766 non-null  int64
# dtypes: bool(1), float64(3), int64(2), object(11)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#             Przebieg  Poj. silnika   Moc silnika           Cena          Wiek
# count   11766.000000  11766.000000  11766.000000   11766.000000  11766.000000
# mean   226511.249788   1913.809196    145.179075   29358.962150     15.482917
# std     82659.720544    662.681506     67.298911   33928.855038      5.501227
# min      7000.000000    500.000000     20.000000    1000.000000      1.000000
# 25%    171270.500000   1560.000000    105.000000    9500.000000     11.000000
# 50%    226000.000000   1896.000000    131.000000   18900.000000     16.000000
# 75%    279000.000000   2000.000000    165.000000   36500.000000     19.000000
# max    560214.000000   6500.000000    710.000000  505000.000000     35.000000

# %%
for col in df:
    print(f'{col}: {df[col].isnull().sum()} brakujących danych')
# Out:
# Model: 0 brakujących danych
# Paliwo: 0 brakujących danych
# Typ nadwozia: 0 brakujących danych
# Przebieg: 0 brakujących danych
# Kolor: 0 brakujących danych
# Poj. silnika: 0 brakujących danych
# Skrzynia biegów: 0 brakujących danych
# Kraj pochodzenia: 0 brakujących danych
# Moc silnika: 0 brakujących danych
# Napęd: 0 brakujących danych
# Kierownica: 0 brakujących danych
# Cena: 0 brakujących danych
# Województwo: 0 brakujących danych
# Rodzaj ogłoszenia: 0 brakujących danych
# Producent: 0 brakujących danych
# Czy cena do negocjacji: 0 brakujących danych
# Wiek: 0 brakujących danych

# %%
atrybuty_ilosciowe = df.select_dtypes(include=['number'])
atrybuty_ilosciowe.nunique()
# Out:
# Przebieg        3442
# Poj. silnika     460
# Moc silnika      342
# Cena            1204
# Wiek              35
# dtype: int64

# %%
plt.figure(figsize=(15, 5))
plt.xticks(np.arange(0, 500001, step=50000))
sns.histplot(x=df["Cena"],bins=50, kde=True)
plt.show()
plt.figure(figsize=(15, 5))
sns.histplot(x=df["Cena"],bins=50, kde=True, log_scale=True)
plt.show()

# %% [markdown]
# Widać wyraźną lewoskośność histogramu, a zdecydowana większość aut kosztuje nie więcej niż 100000 złotych. Po przeskalowaniu na skalę logarytmiczną histogram staje się symetryczny.

# %%
atrybuty_ilosciowe_bez_ceny=atrybuty_ilosciowe.drop(columns=["Cena"])
for i in atrybuty_ilosciowe_bez_ceny.columns:
    plt.figure(figsize=(15, 5))
    sns.histplot(atrybuty_ilosciowe[i], bins=35, kde=True)
    plt.show()

# %% [markdown]
# Histogramy dla parametrów wiek oraz przebieg są symetryczne, a dla mocy silnika — lewoskośny. Histogram pojemności silnika jest wielomodalny: najwyższy grzbiet widoczny jest w okolicach 2 litrów.

# %%
for i in atrybuty_ilosciowe_bez_ceny.columns:
    plt.figure(figsize=(15, 5))
    sns.boxplot(x=atrybuty_ilosciowe_bez_ceny[i])
    plt.show()
for i in atrybuty_ilosciowe_bez_ceny.columns:
    plt.figure(figsize=(15, 5))
    sns.scatterplot(x=atrybuty_ilosciowe_bez_ceny[i], y=atrybuty_ilosciowe["Cena"])
    plt.show()

# %% [markdown]
# Większość analizowanych aut ma silniki o pojemności z zakresu 1,5-2 litrów oraz mocy od 105 do 165 KM, a także zostało wyprodukowane pomiędzy 11 a 19 lat temu. Przeciętne auto na OLXie ma przejechane ponad 200 tysięcy kilometrów.

# %% [markdown]
# Cena auta spada wraz ze wzrostem przebiegu oraz wieku, a rośnie razem z mocą i pojemnością silnika.

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(atrybuty_ilosciowe.corr(), annot=True, cmap="vlag")
# Out:
# <Axes: >

# %% [markdown]
# Najbardziej skorelowane ze sobą są pary Moc-Pojemność, Moc-Cena oraz Cena-Wiek. Prawie nie ma korelacji pomiędzy mocą silnika a przebiegiem.

# %%
atrybuty_kategoryczne = df.select_dtypes(object, bool)
atrybuty_kategoryczne.nunique()
# Out:
# Model                642
# Paliwo                 3
# Typ nadwozia          10
# Kolor                 10
# Skrzynia biegów        2
# Kraj pochodzenia      32
# Napęd                  6
# Kierownica             3
# Województwo           16
# Rodzaj ogłoszenia      2
# Producent             53
# dtype: int64

# %%
atrybuty_kategoryczne_bez_modeli = atrybuty_kategoryczne.drop(columns=["Model"])
for i in atrybuty_kategoryczne_bez_modeli.columns:
    category_order = atrybuty_kategoryczne_bez_modeli[i].value_counts().index.tolist()
    plt.figure(figsize=(15, 0.3 * atrybuty_kategoryczne_bez_modeli[i].nunique()))
    plot = sns.countplot(atrybuty_kategoryczne_bez_modeli[i], order=category_order)
    plot.bar_label(plot.containers[0])
    plt.show()

# %%
for i in atrybuty_kategoryczne_bez_modeli.columns:
    category_order = atrybuty_kategoryczne_bez_modeli[i].value_counts().index.tolist()
    plt.figure(figsize=(15, 0.3 * atrybuty_kategoryczne_bez_modeli[i].nunique()))
    plot = sns.barplot(data=df, x="Cena", y=i, order=category_order, orient="h")
    plot.bar_label(plot.containers[0], label_type="center", color="black")
    plt.show()
